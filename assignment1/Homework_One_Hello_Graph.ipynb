# %% [markdown]
# ### Homework One: Hello, Graph World
# **Term:** Summer 2021
#
# **Author:** Claire Meyer

# %%
import networkx as net

# %% [markdown]
# The code below creates a graph. I created this graph manually, to reflect my family tree - my parents, their siblings, and those siblings' children.
#
# First, I initialize a graph.

# %%
kite_graph=net.Graph()

# %% [markdown]
# Then I add my nodes and edges. This is admittedly a little inconsistent, but I've created an edge for each of my parents to their siblings, and then those siblings and my parents to their children.

# %%
kite_graph.add_edge('Ike','Jane')
kite_graph.add_edge('Heather','Ike')
kite_graph.add_edge('Fernando','Heather')
kite_graph.add_edge('Garth','Heather')
kite_graph.add_edge('Fernando','Garth')
kite_graph.add_edge('Diane','Fernando')
kite_graph.add_edge('Diane','Garth')
kite_graph.add_edge('Carol','Fernando')
kite_graph.add_edge('Ed','Garth')
kite_graph.add_edge('Carol','Diane')
kite_graph.add_edge('Ed','Diane')
kite_graph.add_edge('Beverly','Ed')
kite_graph.add_edge('Beverly','Diane')
kite_graph.add_edge('Beverly','Garth')
kite_graph.add_edge('Andre','Carol')
kite_graph.add_edge('Andre','Diane')
kite_graph.add_edge('Andre','Fernando')
kite_graph.add_edge('Andre','Beverly')

# %% [markdown]
# Then I can draw a simple graph of these nodes and edges.

# %%
net.draw_networkx(kite_graph)
